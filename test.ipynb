# %%
from liuembeddings import LiuEmbeddings
from liuembeddings import LiuVectorStore
from liuembeddings import split_text, clean

print("\nInitializing embedding model and vector store...")

embedder = LiuEmbeddings(model_name="USE")

vector_store = LiuVectorStore(
    embedding_model=embedder,
    collection_name="ml_knowledge"
)
# Out:
# WARNING:tensorflow:From c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# 2025-10-25 19:41:40,639 - liuembeddings.embeddings - INFO - Loading model 'USE' from https://tfhub.dev/google/universal-sentence-encoder/4
# Initializing embedding model and vector store...
# WARNING:tensorflow:From c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
#
# 2025-10-25 19:41:45,724 - liuembeddings.embeddings - INFO - ✅ Loaded 'USE' model (dimension: 512)
# INFO:liuembeddings.embeddings:✅ Loaded 'USE' model (dimension: 512)
# 2025-10-25 19:41:45,727 - liuembeddings.vectorstore - INFO - Initializing ChromaDB at ./chroma_db
# INFO:liuembeddings.vectorstore:Initializing ChromaDB at ./chroma_db
# 2025-10-25 19:41:46,149 - liuembeddings.vectorstore - INFO - ✅ Initialized collection 'ml_knowledge' (documents: 1)
# INFO:liuembeddings.vectorstore:✅ Initialized collection 'ml_knowledge' (documents: 1)

# %%
print("=" * 60)
print("Example 1: Basic Embedding")
print("=" * 60)

# Single query embedding
query_embedding = embedder.embed_query("What is machine learning?")
print(f"Query embedding dimension: {len(query_embedding)}")
print(f"First 5 values: {query_embedding[:5]}")

# Multiple documents
documents = [
    "Machine learning is a subset of AI",
    "Deep learning uses neural networks",
    "Natural language processing handles text"
]

doc_embeddings = embedder.embed_documents(documents)
print(f"\nEmbedded {len(doc_embeddings)} documents")
# Out:
# ============================================================
# Example 1: Basic Embedding
# ============================================================
# 2025-10-25 19:41:46,700 - liuembeddings.embeddings - INFO - Embedded 3 documents
# INFO:liuembeddings.embeddings:Embedded 3 documents
# Query embedding dimension: 512
# First 5 values: [-0.004198556765913963, -0.07223273068666458, -0.06091027706861496, -0.007246586959809065, -0.022054186090826988]
#
# Embedded 3 documents

# %%
# Example 2: Text Processing
print("\n" + "=" * 60)
print("Example 2: Text Processing & Chunking")
print("=" * 60)

long_text = """
Machine learning is a powerful and rapidly growing method of data analysis that automates the process of building analytical models. It belongs to the broader field of artificial intelligence (AI), which focuses on creating systems that can simulate aspects of human intelligence. The central idea behind machine learning is that computers can be trained to learn from data, recognize patterns, and make informed decisions with little or no direct human intervention.

In traditional programming, humans explicitly write rules and logic for a computer to follow. However, in machine learning, these rules are not hard-coded. Instead, the system uses algorithms that allow it to learn and improve automatically from experience. The more data it receives, the better it becomes at identifying patterns, relationships, and insights that may not be obvious to humans. This ability to adapt and refine itself makes machine learning extremely valuable for handling complex and large-scale data problems.

The learning process begins with observations or data — these could come from examples, historical records, direct measurements, or real-world experiences. The model examines the data to detect recurring trends, correlations, or hidden patterns. Using this knowledge, it develops a mathematical representation that can be applied to new data to predict outcomes or make decisions. Over time, as more examples are processed, the model continuously updates and becomes more accurate.

Machine learning can be applied to an astonishing variety of real-world scenarios. For example, in healthcare, it helps predict diseases, recommend treatments, and analyze medical images. In finance, it detects fraudulent transactions and supports algorithmic trading. In e-commerce, machine learning powers recommendation engines that suggest products based on user behavior. Even in daily life, it appears in voice assistants like Siri or Alexa, which improve through constant interaction with users.

There are several types of machine learning approaches, including supervised learning, unsupervised learning, semi-supervised learning, and reinforcement learning. Supervised learning involves training a model with labeled data, where the correct output is known, while unsupervised learning deals with unlabeled data, letting the system find structure on its own. Reinforcement learning, on the other hand, trains models through trial and error, rewarding successful outcomes and penalizing mistakes. Each approach has unique strengths and is suited to different kinds of problems.

Ultimately, the goal of machine learning is to enable computers to make better and more autonomous decisions over time, based on the information they encounter. By continuously learning from new data, these systems can adjust their strategies, correct errors, and enhance performance without explicit reprogramming. This capability represents a major step toward the development of intelligent systems that can assist humans in solving complex challenges and making data-driven decisions with unprecedented speed and precision.

""" 


# Split into chunks
chunks = split_text(long_text, chunk_size=400, chunk_overlap=50)
print(f"\nSplit into {len(chunks)} chunks:")
for i, chunk in enumerate(chunks, 1):
    print(f"  Chunk {i}: {chunk[:60]}...")


#add cleaned chunks to vector store
vector_store.add_texts(chunks)

# Query the vector store
print("\nQuerying the vector store...")
raw,ans =vector_store.query("What techniques improve model accuracy?", n_results=2)


for i, chunk in enumerate(ans, 1):
    print(f"  answer {i}: {chunk[:150]}...")


#cleaning raw data:
clean_output = clean(raw)

for i in clean_output:
    print(i)
# Out:
# 2025-10-25 19:41:46,723 - liuembeddings.utils - INFO - Split text into 9 chunks (size: 400, overlap: 50)
# INFO:liuembeddings.utils:Split text into 9 chunks (size: 400, overlap: 50)
# 2025-10-25 19:41:46,736 - liuembeddings.embeddings - INFO - Embedded 9 documents
# INFO:liuembeddings.embeddings:Embedded 9 documents
# 2025-10-25 19:41:46,821 - liuembeddings.vectorstore - INFO - ✅ Added 9 documents to 'ml_knowledge'
# ============================================================
# Example 2: Text Processing & Chunking
# ============================================================
#
# Split into 9 chunks:
#   Chunk 1: machine learning is a powerful and rapidly growing method of...
#   Chunk 2: the central idea behind machine learning is that computers c...
#   Chunk 3: instead, the system uses algorithms that allow it to learn a...
#   Chunk 4: the learning process begins with observations or data — thes...
#   Chunk 5: over time, as more examples are processed, the model continu...
#   Chunk 6: in e-commerce, machine learning powers recommendation engine...
#   Chunk 7: supervised learning involves training a model with labeled d...
#   Chunk 8: each approach has unique strengths and is suited to differen...
#   Chunk 9: this capability represents a major step toward the developme...
# INFO:liuembeddings.vectorstore:✅ Added 9 documents to 'ml_knowledge'
# 2025-10-25 19:41:46,827 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# 2025-10-25 19:41:46,891 - liuembeddings.vectorstore - INFO - Query returned 2 results
# INFO:liuembeddings.vectorstore:Query returned 2 results
# 2025-10-25 19:41:46,893 - liuembeddings.utils - INFO - Raw data cleaning........................
# INFO:liuembeddings.utils:Raw data cleaning........................
# Querying the vector store...
#   answer 1: supervised learning involves training a model with labeled data, where the correct output is known, while unsupervised learning deals with unlabeled d...
#   answer 2: machine learning is a powerful and rapidly growing method of data analysis... feature engineering is crucial for model performance......
# {'id': 'doc_6_1761401506726_9cbf3f', 'document': 'supervised learning involves training a model with labeled data, where the correct output is known, while unsupervised learning deals with unlabeled data, letting the system find structure on its own. reinforcement learning, on the other hand, trains models through trial and error, rewarding successful outcomes and penalizing mistakes.', 'metadata': {'source': 'ml_knowledge'}, 'distance': 0.7587209343910217}
# {'id': 'doc_0_1761401259744_1b0cf4', 'document': 'machine learning is a powerful and rapidly growing method of data analysis... feature engineering is crucial for model performance...', 'metadata': {'source': 'ml_knowledge'}, 'distance': 0.7753744125366211}

# %%
# Example 3: Vector Store Operations
print("\n" + "=" * 60)
print("Example 3: Vector Store CRUD Operations")
print("=" * 60)



# Add documents
docs_to_store = [
    "Machine learning is used for predictive analysis",
    "Deep learning requires large amounts of data",
    "Feature engineering is crucial for model performance"
]
vector_store.add_texts(docs_to_store)
print(f"Added {vector_store.count_documents()} documents")

# Search
raw,results = vector_store.similarity_search(
    "What techniques improve model accuracy?",
    n_results=1
)



print(f"\nSearch results:")
for i, result in enumerate(results, 1):
    print(f"  Result {i} (score: {result['similarity_score']:.3f})")
    print(f"    {result['document'][:60]}...")

#print(results)




# Update document
print("\nUpdating first document...")
vector_store.update_by_id(
    results[0]['id'],
    "Machine learning drives innovation and efficiency"
)

# Search by ID
print(f"\nRetrieving by ID: {results[0]['id']}")
retrieved = vector_store.search_by_id(results[0]['id'])
print(f"  {retrieved['document']}")

# Get all documents
all_docs = vector_store.get_all()
print(f"\nTotal documents in store: {len(all_docs)}")
# Out:
# 2025-10-25 19:41:46,919 - liuembeddings.embeddings - INFO - Embedded 3 documents
# INFO:liuembeddings.embeddings:Embedded 3 documents
# 2025-10-25 19:41:46,940 - liuembeddings.vectorstore - INFO - ✅ Added 3 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 3 documents to 'ml_knowledge'
# 2025-10-25 19:41:46,952 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# ============================================================
# Example 3: Vector Store CRUD Operations
# ============================================================
# Added 13 documents
#
# Search results:
#   Result 1 (score: 0.338)
#     Feature engineering is crucial for model performance...
#
# Updating first document...
# 2025-10-25 19:41:47,142 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# 2025-10-25 19:41:47,166 - liuembeddings.vectorstore - INFO - ✅ Updated document 'doc_2_1761401506912_d27a7c'
# INFO:liuembeddings.vectorstore:✅ Updated document 'doc_2_1761401506912_d27a7c'
# 2025-10-25 19:41:47,174 - liuembeddings.vectorstore - INFO - Retrieved 13 total documents
# INFO:liuembeddings.vectorstore:Retrieved 13 total documents
# Retrieving by ID: doc_2_1761401506912_d27a7c
#   Machine learning drives innovation and efficiency
#
# Total documents in store: 13

# %%
# Example 4: Batch Processing
print("\n" + "=" * 60)
print("Example 4: Batch Processing Large Documents")
print("=" * 60)

# Create many documents Optional onlycreating
large_doc_set = [f"Document number {i} with content about topic {i % 5}" 
                 for i in range(25)]

embedder_batch = LiuEmbeddings()
embeddings_batch = embedder_batch.embed_documents_batch(
    large_doc_set,
    batch_size=10
)
print(f"Processed {len(embeddings_batch)} documents in batches")


#batch storing (batch of 10 in each run 10 document will be added)

# 20 sample documents
texts = [f"Document {i+1}: This is sample text for document {i+1}." for i in range(100)]

# Optional metadata
metadatas = [{"source":"Batch of 5"} for i in range(100)]

vector_store.add_texts_batch(
    texts,
    batch_size=10,
    metadatas=metadatas
)

results=vector_store.search_by_metadata({"source":"Batch of 5"})

for i, result in enumerate(results, 1):
    print(f"   id: {result['id']}")
    print(f"    {result['document'][:60]}...")
# Out:
# 2025-10-25 19:41:47,199 - liuembeddings.embeddings - INFO - ✅ Loaded 'USE' model (dimension: 512)
# INFO:liuembeddings.embeddings:✅ Loaded 'USE' model (dimension: 512)
# 2025-10-25 19:41:47,201 - liuembeddings.embeddings - INFO - Processing 25 documents in 3 batches
# INFO:liuembeddings.embeddings:Processing 25 documents in 3 batches
# 2025-10-25 19:41:47,210 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,220 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,228 - liuembeddings.embeddings - INFO - Embedded 5 documents
# INFO:liuembeddings.embeddings:Embedded 5 documents
# 2025-10-25 19:41:47,232 - liuembeddings.embeddings - INFO - ✅ Batch processing complete (25 documents)
# INFO:liuembeddings.embeddings:✅ Batch processing complete (25 documents)
# 2025-10-25 19:41:47,236 - liuembeddings.vectorstore - INFO - Adding 100 documents in 10 batches
# INFO:liuembeddings.vectorstore:Adding 100 documents in 10 batches
# 2025-10-25 19:41:47,246 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,277 - liuembeddings.vectorstore - INFO - ✅ Added 10 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 10 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,287 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,316 - liuembeddings.vectorstore - INFO - ✅ Added 10 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 10 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,324 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,353 - liuembeddings.vectorstore - INFO - ✅ Added 10 documents to 'ml_knowledge'
# ============================================================
# Example 4: Batch Processing Large Documents
# ============================================================
# Processed 25 documents in batches
# INFO:liuembeddings.vectorstore:✅ Added 10 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,363 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,395 - liuembeddings.vectorstore - INFO - ✅ Added 10 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 10 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,403 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,434 - liuembeddings.vectorstore - INFO - ✅ Added 10 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 10 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,442 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,474 - liuembeddings.vectorstore - INFO - ✅ Added 10 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 10 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,483 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,513 - liuembeddings.vectorstore - INFO - ✅ Added 10 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 10 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,524 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,558 - liuembeddings.vectorstore - INFO - ✅ Added 10 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 10 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,569 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,601 - liuembeddings.vectorstore - INFO - ✅ Added 10 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 10 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,609 - liuembeddings.embeddings - INFO - Embedded 10 documents
# INFO:liuembeddings.embeddings:Embedded 10 documents
# 2025-10-25 19:41:47,642 - liuembeddings.vectorstore - INFO - ✅ Added 10 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 10 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,644 - liuembeddings.vectorstore - INFO - ✅ Batch addition complete
# INFO:liuembeddings.vectorstore:✅ Batch addition complete
# 2025-10-25 19:41:47,651 - liuembeddings.vectorstore - INFO - Metadata search returned 100 results
# INFO:liuembeddings.vectorstore:Metadata search returned 100 results
#    id: doc_0_1761401507240_152a8e
#     Document 1: This is sample text for document 1....
#    id: doc_1_1761401507240_3e6a80
#     Document 2: This is sample text for document 2....
#    id: doc_2_1761401507240_b5f66a
#     Document 3: This is sample text for document 3....
#    id: doc_3_1761401507240_a3acb7
#     Document 4: This is sample text for document 4....
#    id: doc_4_1761401507240_2bc9b3
#     Document 5: This is sample text for document 5....
#    id: doc_5_1761401507240_270104
#     Document 6: This is sample text for document 6....
#    id: doc_6_1761401507240_3ab093
#     Document 7: This is sample text for document 7....
#    id: doc_7_1761401507240_7dcae3
#     Document 8: This is sample text for document 8....
#    id: doc_8_1761401507240_2a7b1b
#     Document 9: This is sample text for document 9....
#    id: doc_9_1761401507240_0d5cf6
#     Document 10: This is sample text for document 10....
#    id: doc_0_1761401507282_dbe05d
#     Document 11: This is sample text for document 11....
#    id: doc_1_1761401507282_f11b89
#     Document 12: This is sample text for document 12....
#    id: doc_2_1761401507282_e9a49e
#     Document 13: This is sample text for document 13....
#    id: doc_3_1761401507282_77fa1a
#     Document 14: This is sample text for document 14....
#    id: doc_4_1761401507282_8a9c66
#     Document 15: This is sample text for document 15....
#    id: doc_5_1761401507282_18ba15
#     Document 16: This is sample text for document 16....
#    id: doc_6_1761401507282_7f9eb5
#     Document 17: This is sample text for document 17....
#    id: doc_7_1761401507282_a952e3
#     Document 18: This is sample text for document 18....
#    id: doc_8_1761401507282_052db1
#     Document 19: This is sample text for document 19....
#    id: doc_9_1761401507282_96af3e
#     Document 20: This is sample text for document 20....
#    id: doc_0_1761401507318_61921d
#     Document 21: This is sample text for document 21....
#    id: doc_1_1761401507318_6a1dca
#     Document 22: This is sample text for document 22....
#    id: doc_2_1761401507318_22c254
#     Document 23: This is sample text for document 23....
#    id: doc_3_1761401507318_99f36e
#     Document 24: This is sample text for document 24....
#    id: doc_4_1761401507318_939ee3
#     Document 25: This is sample text for document 25....
#    id: doc_5_1761401507318_5a2ea1
#     Document 26: This is sample text for document 26....
#    id: doc_6_1761401507318_390c26
#     Document 27: This is sample text for document 27....
#    id: doc_7_1761401507318_481f39
#     Document 28: This is sample text for document 28....
#    id: doc_8_1761401507318_b51431
#     Document 29: This is sample text for document 29....
#    id: doc_9_1761401507318_9f3e76
#     Document 30: This is sample text for document 30....
#    id: doc_0_1761401507357_f61b6c
#     Document 31: This is sample text for document 31....
#    id: doc_1_1761401507357_c8cc75
#     Document 32: This is sample text for document 32....
#    id: doc_2_1761401507357_3ea55b
#     Document 33: This is sample text for document 33....
#    id: doc_3_1761401507357_2ef946
#     Document 34: This is sample text for document 34....
#    id: doc_4_1761401507357_339d11
#     Document 35: This is sample text for document 35....
#    id: doc_5_1761401507357_39add3
#     Document 36: This is sample text for document 36....
#    id: doc_6_1761401507357_4b5deb
#     Document 37: This is sample text for document 37....
#    id: doc_7_1761401507357_672910
#     Document 38: This is sample text for document 38....
#    id: doc_8_1761401507357_6d9c06
#     Document 39: This is sample text for document 39....
#    id: doc_9_1761401507357_c88b1f
#     Document 40: This is sample text for document 40....
#    id: doc_0_1761401507398_3d9f43
#     Document 41: This is sample text for document 41....
#    id: doc_1_1761401507398_2fd354
#     Document 42: This is sample text for document 42....
#    id: doc_2_1761401507398_526daa
#     Document 43: This is sample text for document 43....
#    id: doc_3_1761401507398_a7ff61
#     Document 44: This is sample text for document 44....
#    id: doc_4_1761401507398_89ec8f
#     Document 45: This is sample text for document 45....
#    id: doc_5_1761401507398_8bf7c1
#     Document 46: This is sample text for document 46....
#    id: doc_6_1761401507398_b1a842
#     Document 47: This is sample text for document 47....
#    id: doc_7_1761401507398_d75e1d
#     Document 48: This is sample text for document 48....
#    id: doc_8_1761401507398_8952e7
#     Document 49: This is sample text for document 49....
#    id: doc_9_1761401507398_28366c
#     Document 50: This is sample text for document 50....
#    id: doc_0_1761401507437_e525be
#     Document 51: This is sample text for document 51....
#    id: doc_1_1761401507437_66e8f5
#     Document 52: This is sample text for document 52....
#    id: doc_2_1761401507437_ed8b56
#     Document 53: This is sample text for document 53....
#    id: doc_3_1761401507437_0ddc91
#     Document 54: This is sample text for document 54....
#    id: doc_4_1761401507437_bacecd
#     Document 55: This is sample text for document 55....
#    id: doc_5_1761401507437_6fb6af
#     Document 56: This is sample text for document 56....
#    id: doc_6_1761401507437_04c99a
#     Document 57: This is sample text for document 57....
#    id: doc_7_1761401507437_3666d9
#     Document 58: This is sample text for document 58....
#    id: doc_8_1761401507437_bb57bb
#     Document 59: This is sample text for document 59....
#    id: doc_9_1761401507437_7f274c
#     Document 60: This is sample text for document 60....
#    id: doc_0_1761401507477_61c9ea
#     Document 61: This is sample text for document 61....
#    id: doc_1_1761401507477_660dd3
#     Document 62: This is sample text for document 62....
#    id: doc_2_1761401507477_44fb19
#     Document 63: This is sample text for document 63....
#    id: doc_3_1761401507477_f8c1fa
#     Document 64: This is sample text for document 64....
#    id: doc_4_1761401507477_c62021
#     Document 65: This is sample text for document 65....
#    id: doc_5_1761401507477_127ae5
#     Document 66: This is sample text for document 66....
#    id: doc_6_1761401507477_f397ea
#     Document 67: This is sample text for document 67....
#    id: doc_7_1761401507477_e5fe40
#     Document 68: This is sample text for document 68....
#    id: doc_8_1761401507477_8b2c16
#     Document 69: This is sample text for document 69....
#    id: doc_9_1761401507477_d966e3
#     Document 70: This is sample text for document 70....
#    id: doc_0_1761401507517_096a5a
#     Document 71: This is sample text for document 71....
#    id: doc_1_1761401507517_13a3b1
#     Document 72: This is sample text for document 72....
#    id: doc_2_1761401507517_cd0507
#     Document 73: This is sample text for document 73....
#    id: doc_3_1761401507517_b7f5a8
#     Document 74: This is sample text for document 74....
#    id: doc_4_1761401507517_f73590
#     Document 75: This is sample text for document 75....
#    id: doc_5_1761401507518_fccb61
#     Document 76: This is sample text for document 76....
#    id: doc_6_1761401507518_05726e
#     Document 77: This is sample text for document 77....
#    id: doc_7_1761401507518_796142
#     Document 78: This is sample text for document 78....
#    id: doc_8_1761401507518_ff28cd
#     Document 79: This is sample text for document 79....
#    id: doc_9_1761401507518_3eef9e
#     Document 80: This is sample text for document 80....
#    id: doc_0_1761401507563_9ae35c
#     Document 81: This is sample text for document 81....
#    id: doc_1_1761401507563_7e337e
#     Document 82: This is sample text for document 82....
#    id: doc_2_1761401507563_611d2c
#     Document 83: This is sample text for document 83....
#    id: doc_3_1761401507563_b38ed3
#     Document 84: This is sample text for document 84....
#    id: doc_4_1761401507563_47ee6b
#     Document 85: This is sample text for document 85....
#    id: doc_5_1761401507564_caf16f
#     Document 86: This is sample text for document 86....
#    id: doc_6_1761401507564_1ff695
#     Document 87: This is sample text for document 87....
#    id: doc_7_1761401507564_0364b4
#     Document 88: This is sample text for document 88....
#    id: doc_8_1761401507564_f8beb5
#     Document 89: This is sample text for document 89....
#    id: doc_9_1761401507564_478079
#     Document 90: This is sample text for document 90....
#    id: doc_0_1761401507603_0be42b
#     Document 91: This is sample text for document 91....
#    id: doc_1_1761401507603_6ce697
#     Document 92: This is sample text for document 92....
#    id: doc_2_1761401507603_1d1d37
#     Document 93: This is sample text for document 93....
#    id: doc_3_1761401507603_ab8144
#     Document 94: This is sample text for document 94....
#    id: doc_4_1761401507603_de0831
#     Document 95: This is sample text for document 95....
#    id: doc_5_1761401507603_23d108
#     Document 96: This is sample text for document 96....
#    id: doc_6_1761401507603_daa340
#     Document 97: This is sample text for document 97....
#    id: doc_7_1761401507603_ca5386
#     Document 98: This is sample text for document 98....
#    id: doc_8_1761401507603_6d0f49
#     Document 99: This is sample text for document 99....
#    id: doc_9_1761401507603_48d1e7
#     Document 100: This is sample text for document 100....

# %%
# Example 5: One-Line Search one function ultimate usage
print("\n" + "=" * 60)
print("Example 5: One-Line Semantic Search")
print("=" * 60)

print("\nPerforming another semantic search using search... \n only adding document")
document = """
my name is himanshu i am a data engineer working in tcs india pvt ltd.
i have experience in spark,hadoop,python,sql,azure,aws,tableau,power bi etc.
i love to work on data and build data pipelines and dashboards.
python is a high-level programming language known for its simplicity but it is not simple :).
""" 


#adding only
vector_store.search(
    text_document=document,
    chunk_size=250,
    chunk_overlap=100,
)


print("\nPerforming another semantic search using liu_search... \n only searching")
#searching only
raw,ans = vector_store.search(
    query="What himanshu does for a living?",
    n_results=1
)




document = """
Python is a high-level programming language known for its simplicity.
JavaScript is used primarily for web development.
Java is popular for enterprise applications.
C++ is known for high performance and system programming.
""" * 2

#do not repat addition thing twice leads to multi data storage

#adding and searching in one line
raw,ans = vector_store.search(
    query="What language is best for web development?",
    text_document=document,
    n_results=1

)

for i in range(len(ans)):
    print(f"  Result {i+1}: {ans[i][:90]}...")




print("\nPerforming another semantic search using search... \n only adding document")
document = """
my name is himanshu i am a data engineer working in tcs india pvt ltd.
i have experience in spark,hadoop,python,sql,azure,aws,tableau,power bi etc.
i love to work on data and build data pipelines and dashboards.
python is a high-level programming language known for its simplicity but it is not simple :).
"""
# Out:
# 2025-10-25 19:41:47,676 - liuembeddings.vectorstore - INFO - Starting liu_search operation
# INFO:liuembeddings.vectorstore:Starting liu_search operation
# 2025-10-25 19:41:47,680 - liuembeddings.vectorstore - INFO - Splitting text (size: 250, overlap: 100)
# INFO:liuembeddings.vectorstore:Splitting text (size: 250, overlap: 100)
# 2025-10-25 19:41:47,682 - liuembeddings.utils - INFO - Split text into 2 chunks (size: 250, overlap: 100)
# INFO:liuembeddings.utils:Split text into 2 chunks (size: 250, overlap: 100)
# 2025-10-25 19:41:47,685 - liuembeddings.vectorstore - INFO - Adding 2 chunks to vector store
# INFO:liuembeddings.vectorstore:Adding 2 chunks to vector store
# 2025-10-25 19:41:47,692 - liuembeddings.embeddings - INFO - Embedded 2 documents
# INFO:liuembeddings.embeddings:Embedded 2 documents
# 2025-10-25 19:41:47,717 - liuembeddings.vectorstore - INFO - ✅ Added 2 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 2 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,719 - liuembeddings.vectorstore - INFO - Searching for: 'What himanshu does for a living?'
# INFO:liuembeddings.vectorstore:Searching for: 'What himanshu does for a living?'
# 2025-10-25 19:41:47,726 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# 2025-10-25 19:41:47,731 - liuembeddings.vectorstore - INFO - Query returned 1 results
# INFO:liuembeddings.vectorstore:Query returned 1 results
# 2025-10-25 19:41:47,734 - liuembeddings.vectorstore - INFO - ✅ Search complete. Found 2 results
# INFO:liuembeddings.vectorstore:✅ Search complete. Found 2 results
# 2025-10-25 19:41:47,736 - liuembeddings.vectorstore - INFO - Starting liu_search operation
# INFO:liuembeddings.vectorstore:Starting liu_search operation
# 2025-10-25 19:41:47,738 - liuembeddings.vectorstore - INFO - Splitting text (size: 1000, overlap: 200)
# INFO:liuembeddings.vectorstore:Splitting text (size: 1000, overlap: 200)
# 2025-10-25 19:41:47,740 - liuembeddings.utils - INFO - Split text into 1 chunks (size: 1000, overlap: 200)
# INFO:liuembeddings.utils:Split text into 1 chunks (size: 1000, overlap: 200)
# 2025-10-25 19:41:47,741 - liuembeddings.vectorstore - INFO - Adding 1 chunks to vector store
# INFO:liuembeddings.vectorstore:Adding 1 chunks to vector store
# 2025-10-25 19:41:47,747 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# 2025-10-25 19:41:47,771 - liuembeddings.vectorstore - INFO - ✅ Added 1 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 1 documents to 'ml_knowledge'
# 2025-10-25 19:41:47,774 - liuembeddings.vectorstore - INFO - Searching for: 'What language is best for web development?'
# INFO:liuembeddings.vectorstore:Searching for: 'What language is best for web development?'
# 2025-10-25 19:41:47,780 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# 2025-10-25 19:41:47,786 - liuembeddings.vectorstore - INFO - Query returned 1 results
# INFO:liuembeddings.vectorstore:Query returned 1 results
# 2025-10-25 19:41:47,788 - liuembeddings.vectorstore - INFO - ✅ Search complete. Found 2 results
# INFO:liuembeddings.vectorstore:✅ Search complete. Found 2 results
# ============================================================
# Example 5: One-Line Semantic Search
# ============================================================
#
# Performing another semantic search using search...
#  only adding document
#
# Performing another semantic search using liu_search...
#  only searching
#   Result 1: python is a high-level programming language known for its simplicity. javascript is used p...
#
# Performing another semantic search using search...
#  only adding document

# %% [markdown]
# # FASTQUERY

# %%
#fastquery same as vector_store.search
#no embeding needed just searching only
from liuembeddings import fastquery,clean

print("\nPerforming another semantic search using fastquery... \n only adding document")


document = """
my name is himanshu i am a data engineer working in tcs india pvt ltd.
i have experience in spark,hadoop,python,sql,azure,aws,tableau,power bi etc.
i love to work on data and build data pipelines and dashboards.
python is a high-level programming language known for its simplicity but it is not simple :).
""" 

#i recommend to use same collection_name in the fromat of minimal_collection name 
fastquery.collection_name="minimal_collection"

#adding only
fastquery(
    text_document=document,
    chunk_size=80,
    chunk_overlap=10,
    n_results=1,
)

#searching only
raw,ans= fastquery(
    query="What himanshu does for a living?",
    n_results=1,
)


for i in ans:  #getting only documents from returned tuple
    print(f"  Result: {i[:75]}.....")
# Out:
# 2025-10-25 19:42:25,632 - liuembeddings.embeddings - INFO - ✅ Loaded 'USE' model (dimension: 512)
# INFO:liuembeddings.embeddings:✅ Loaded 'USE' model (dimension: 512)
# 2025-10-25 19:42:25,635 - liuembeddings.vectorstore - INFO - Initializing ChromaDB at ./chroma_db
# INFO:liuembeddings.vectorstore:Initializing ChromaDB at ./chroma_db
# 2025-10-25 19:42:25,736 - liuembeddings.vectorstore - INFO - ✅ Initialized collection 'default_collection' (documents: 0)
# INFO:liuembeddings.vectorstore:✅ Initialized collection 'default_collection' (documents: 0)
# 2025-10-25 19:42:25,737 - liuembeddings.utils - INFO - Split text into 4 chunks (size: 80, overlap: 10)
# INFO:liuembeddings.utils:Split text into 4 chunks (size: 80, overlap: 10)
# 2025-10-25 19:42:25,743 - liuembeddings.embeddings - INFO - Embedded 4 documents
# INFO:liuembeddings.embeddings:Embedded 4 documents
# Performing another semantic search using fastquery...
#  only adding document
# 2025-10-25 19:42:25,828 - liuembeddings.vectorstore - INFO - ✅ Added 4 documents to 'default_collection'
# INFO:liuembeddings.vectorstore:✅ Added 4 documents to 'default_collection'
# 2025-10-25 19:42:25,829 - liuembeddings.embeddings - INFO - ✅ Loaded 'USE' model (dimension: 512)
# INFO:liuembeddings.embeddings:✅ Loaded 'USE' model (dimension: 512)
# 2025-10-25 19:42:25,831 - liuembeddings.vectorstore - INFO - Initializing ChromaDB at ./chroma_db
# INFO:liuembeddings.vectorstore:Initializing ChromaDB at ./chroma_db
# 2025-10-25 19:42:25,911 - liuembeddings.vectorstore - INFO - ✅ Initialized collection 'default_collection' (documents: 4)
# INFO:liuembeddings.vectorstore:✅ Initialized collection 'default_collection' (documents: 4)
# 2025-10-25 19:42:25,915 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# 2025-10-25 19:42:25,953 - liuembeddings.vectorstore - INFO - Query returned 1 results
# INFO:liuembeddings.vectorstore:Query returned 1 results
#   Result: my name is himanshu i am a data engineer working in tcs india pvt ltd......

# %%
document2 = """
Luna loves exploring the night sky. Every weekend, she sets up her telescope on the rooftop to watch distant galaxies.
Her favorite constellation is Orion, and she can identify it even without a telescope.
Last month, she discovered a small comet passing near Jupiter and recorded its movement in her astronomy journal.
"""

raw,ans = fastquery(
    text_document=document2,
    query="What celestial object did Luna discover?",
    chunk_size=75,    #chunk size
    chunk_overlap=15, #overlap size
    n_results=5,       # Limiting to 1 result
    with_scores=True,   #
    collection_name="story_collection", #using different collection name storage name
    model_name='USE'

)

#OUTPUT WILL CHANGE WHEN WITH SCORE
for item in ans:
    print(f"Chunk: {item['document']}")
    print(f"Similarity score: {item['similarity_score']}")


for item in ans:
    if item['similarity_score'] < 0.3:
        print(f"answer: {item['document']}")

#print(ans)
# Out:
# 2025-10-25 19:45:51,833 - liuembeddings.embeddings - INFO - ✅ Loaded 'USE' model (dimension: 512)
# INFO:liuembeddings.embeddings:✅ Loaded 'USE' model (dimension: 512)
# 2025-10-25 19:45:51,836 - liuembeddings.vectorstore - INFO - Initializing ChromaDB at ./chroma_db
# INFO:liuembeddings.vectorstore:Initializing ChromaDB at ./chroma_db
# 2025-10-25 19:45:51,965 - liuembeddings.vectorstore - INFO - ✅ Initialized collection 'story_collection' (documents: 0)
# INFO:liuembeddings.vectorstore:✅ Initialized collection 'story_collection' (documents: 0)
# 2025-10-25 19:45:51,966 - liuembeddings.utils - INFO - Split text into 4 chunks (size: 75, overlap: 15)
# INFO:liuembeddings.utils:Split text into 4 chunks (size: 75, overlap: 15)
# 2025-10-25 19:45:51,970 - liuembeddings.embeddings - INFO - Embedded 4 documents
# INFO:liuembeddings.embeddings:Embedded 4 documents
# 2025-10-25 19:45:52,051 - liuembeddings.vectorstore - INFO - ✅ Added 4 documents to 'story_collection'
# INFO:liuembeddings.vectorstore:✅ Added 4 documents to 'story_collection'
# 2025-10-25 19:45:52,057 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# Chunk: luna loves exploring the night sky.
# Similarity score: 0.5885002017021179
# Chunk: her favorite constellation is orion, and she can identify it even without a telescope.
# Similarity score: 0.46684181690216064
# Chunk: last month, she discovered a small comet passing near jupiter and recorded its movement in her astronomy journal.
# Similarity score: 0.4267597198486328
# Chunk: every weekend, she sets up her telescope on the rooftop to watch distant galaxies.
# Similarity score: 0.2936779260635376
# answer: every weekend, she sets up her telescope on the rooftop to watch distant galaxies.
# [{'id': 'doc_0_1761401751967_13107f', 'document': 'luna loves exploring the night sky.', 'metadata': {'source': 'story_collection'}, 'similarity_score': 0.5885002017021179}, {'id': 'doc_2_1761401751967_abd18d', 'document': 'her favorite constellation is orion, and she can identify it even without a telescope.', 'metadata': {'source': 'story_collection'}, 'similarity_score': 0.46684181690216064}, {'id': 'doc_3_1761401751967_fe4aa9', 'document': 'last month, she discovered a small comet passing near jupiter and recorded its movement in her astronomy journal.', 'metadata': {'source': 'story_collection'}, 'similarity_score': 0.4267597198486328}, {'id': 'doc_1_1761401751967_c95a35', 'document': 'every weekend, she sets up her telescope on the rooftop to watch distant galaxies.', 'metadata': {'source': 'story_collection'}, 'similarity_score': 0.2936779260635376}]
