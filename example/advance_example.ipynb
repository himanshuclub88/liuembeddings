# %%
#adding an external embedding model
#make sure it is compitable with hub
#pass url, dimension , and a name

from liuembeddings import LiuEmbeddings
from liuembeddings import LiuVectorStore
from liuembeddings import LiuConfig 
from liuembeddings import clean


#change the default value in liuconfig
LiuConfig.DEFAULT_SIMILARITY_SEARCH_SCORE_THRESHOLD = 0.3
LiuConfig.DEFAULT_SIMILARITY_SEARCH_TOP_K = 2
LiuConfig.DEFAULT_CHUNK_SIZE = 500
LiuConfig.DEFAULT_CHUNK_OVERLAP = 50
LiuConfig.DEFAULT_EMBEDDING_MODEL = 'USE'
LiuConfig.DEFAULT_VECTOR_STORE = 'FAISS'



#cahnge to your own model
LiuConfig.AVAILABLE_MODELS['NNLM'] = {
        'url':"https://tfhub.dev/google/nnlm-en-dim50/2",
        'dimension':50,
        'name':'NNLM (any name of your choice)'
        }

custom_embedder=LiuEmbeddings('NNLM') 

custom_vector = LiuVectorStore(
    embedding_model=custom_embedder,
    collection_name="knowledge-NNLM"
)

# Multiple documents
documents = [
    "all boy's lovewin prize",
    "all boy's love money",
    "all boy's love protein",
    "lorem ipsum lorem ipsum",
    "loremipsum lorem iplorem"
]

custom_vector.add_texts(documents,)

raw,docs=custom_vector.search('what all the boys love')

print("answer:")
for i in docs:
    print(i)


print(clean(raw))
# Out:
# c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING:tensorflow:From c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# 2025-10-29 15:22:43,038 - liuembeddings.embeddings - INFO - Loading model 'NNLM' from https://tfhub.dev/google/nnlm-en-dim50/2
# WARNING:tensorflow:From c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\himan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
#
# 2025-10-29 15:22:44,546 - liuembeddings.embeddings - INFO - ✅ Loaded 'NNLM' model (dimension: 50)
# INFO:liuembeddings.embeddings:✅ Loaded 'NNLM' model (dimension: 50)
# 2025-10-29 15:22:44,549 - liuembeddings.vectorstore - INFO - Initializing ChromaDB at ./liu_db
# INFO:liuembeddings.vectorstore:Initializing ChromaDB at ./liu_db
# 2025-10-29 15:22:44,926 - liuembeddings.vectorstore - INFO - ✅ Initialized collection 'knowledge-NNLM' (documents: 5)
# INFO:liuembeddings.vectorstore:✅ Initialized collection 'knowledge-NNLM' (documents: 5)
# 2025-10-29 15:22:44,972 - liuembeddings.embeddings - INFO - Embedded 5 documents
# INFO:liuembeddings.embeddings:Embedded 5 documents
# 2025-10-29 15:22:45,066 - liuembeddings.vectorstore - INFO - ✅ Added 5 documents to 'knowledge-NNLM'
# INFO:liuembeddings.vectorstore:✅ Added 5 documents to 'knowledge-NNLM'
# 2025-10-29 15:22:45,068 - liuembeddings.vectorstore - INFO - Searching for: 'what all the boys love'
# INFO:liuembeddings.vectorstore:Searching for: 'what all the boys love'
# 2025-10-29 15:22:45,072 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# 2025-10-29 15:22:45,159 - liuembeddings.vectorstore - INFO - Query returned 3 results
# INFO:liuembeddings.vectorstore:Query returned 3 results
# 2025-10-29 15:22:45,163 - liuembeddings.vectorstore - INFO - ✅ Search complete. Found 2 results
# INFO:liuembeddings.vectorstore:✅ Search complete. Found 2 results
# 2025-10-29 15:22:45,166 - liuembeddings.utils - INFO - Raw data cleaning........................
# INFO:liuembeddings.utils:Raw data cleaning........................
# answer:
# all boy's love money
# all boy's love money
# all boy's love protein
# [{'id': 'doc_1_1761731523199_03bcb4', 'document': "all boy's love money", 'metadata': {'source': 'knowledge-NNLM'}, 'distance': 0.40785688161849976}, {'id': 'doc_1_1761731564929_34dc70', 'document': "all boy's love money", 'metadata': {'source': 'knowledge-NNLM'}, 'distance': 0.40785688161849976}, {'id': 'doc_2_1761731564929_261bfd', 'document': "all boy's love protein", 'metadata': {'source': 'knowledge-NNLM'}, 'distance': 0.40857672691345215}]

# %%
#raw output use clean() -> for cleaning
raw={
    'ids': [[
        'doc_2_1761378265744_637001', 
        'doc_2_1761378323980_0ebfd2',
        'doc_2_1761379102815_9ff3a7'
        ]], 

    'embeddings': None, 

    'documents': [[
         "all boy's love protein", 
         "all boy's love protein", 
         "all boy's love protein"
        ]], 

    'uris': None, 

    'included': [
        'metadatas', 
        'documents', 
        'distances'
        ], 

    'data': None, 
    
    'metadatas': [[
        {'source': 'knowledge-NNLM'}, 
        {'source': 'knowledge-NNLM'}, 
        {'source': 'knowledge-NNLM'}
        ]], 

    'distances': [[
        0.40857672691345215,
        0.40857672691345215, 
        0.40857672691345215]]
}

clean_output = [
    {"id": id,"document": doc, "metadata": meta, "distance": dist}
    for id, doc, meta, dist in zip(raw['ids'][0], raw['documents'][0], raw['metadatas'][0], raw['distances'][0])
]

print('\n---manually cleaned raw output---')

# Print manually cleaned raw output
for r in clean_output:
    print(r)

print('\n---cleaned output using clean()---')

#cleaned output using clean()
from liuembeddings import clean
for r in clean(raw):
    print(r)
# Out:
# 2025-10-29 15:22:45,194 - liuembeddings.utils - INFO - Raw data cleaning........................
# INFO:liuembeddings.utils:Raw data cleaning........................
# ---manually cleaned raw output---
# {'id': 'doc_2_1761378265744_637001', 'document': "all boy's love protein", 'metadata': {'source': 'knowledge-NNLM'}, 'distance': 0.40857672691345215}
# {'id': 'doc_2_1761378323980_0ebfd2', 'document': "all boy's love protein", 'metadata': {'source': 'knowledge-NNLM'}, 'distance': 0.40857672691345215}
# {'id': 'doc_2_1761379102815_9ff3a7', 'document': "all boy's love protein", 'metadata': {'source': 'knowledge-NNLM'}, 'distance': 0.40857672691345215}
#
# ---cleaned output using clean()---
# {'id': 'doc_2_1761378265744_637001', 'document': "all boy's love protein", 'metadata': {'source': 'knowledge-NNLM'}, 'distance': 0.40857672691345215}
# {'id': 'doc_2_1761378323980_0ebfd2', 'document': "all boy's love protein", 'metadata': {'source': 'knowledge-NNLM'}, 'distance': 0.40857672691345215}
# {'id': 'doc_2_1761379102815_9ff3a7', 'document': "all boy's love protein", 'metadata': {'source': 'knowledge-NNLM'}, 'distance': 0.40857672691345215}

# %%
from liuembeddings import LiuEmbeddings, LiuVectorStore, split_text, clean

# Initialize
embedder = LiuEmbeddings(model_name="USE")
store = LiuVectorStore(embedder, collection_name="ml_knowledge")

# Long text
long_text = """
Machine learning is a powerful and rapidly growing method of data analysis...
Feature engineering is crucial for model performance...
"""

# Chunk and add
chunks = split_text(long_text, chunk_size=400, chunk_overlap=50)
store.add_texts(chunks)

# Ask a question
raw, docs = store.query("What techniques improve model accuracy?", n_results=2)

# Show the matched chunks
for i, d in enumerate(docs, 1):
    print(f"Answer {i}: {d[:250]}...")

#cleaning raw data:
clean_output = clean(raw)

print('CleanOutput')
for i in clean_output:
    print(i)
# Out:
# 2025-10-29 15:22:45,218 - liuembeddings.embeddings - INFO - Loading model 'USE' from https://tfhub.dev/google/universal-sentence-encoder/4
# INFO:liuembeddings.embeddings:Loading model 'USE' from https://tfhub.dev/google/universal-sentence-encoder/4
# 2025-10-29 15:22:54,560 - liuembeddings.embeddings - INFO - ✅ Loaded 'USE' model (dimension: 512)
# INFO:liuembeddings.embeddings:✅ Loaded 'USE' model (dimension: 512)
# 2025-10-29 15:22:54,562 - liuembeddings.vectorstore - INFO - Initializing ChromaDB at ./liu_db
# INFO:liuembeddings.vectorstore:Initializing ChromaDB at ./liu_db
# 2025-10-29 15:22:54,735 - liuembeddings.vectorstore - INFO - ✅ Initialized collection 'ml_knowledge' (documents: 1)
# INFO:liuembeddings.vectorstore:✅ Initialized collection 'ml_knowledge' (documents: 1)
# 2025-10-29 15:22:54,738 - liuembeddings.utils - INFO - Split text into 1 chunks (size: 400, overlap: 50)
# INFO:liuembeddings.utils:Split text into 1 chunks (size: 400, overlap: 50)
# 2025-10-29 15:22:55,047 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# 2025-10-29 15:22:55,117 - liuembeddings.vectorstore - INFO - ✅ Added 1 documents to 'ml_knowledge'
# INFO:liuembeddings.vectorstore:✅ Added 1 documents to 'ml_knowledge'
# 2025-10-29 15:22:55,122 - liuembeddings.embeddings - INFO - Embedded 1 documents
# INFO:liuembeddings.embeddings:Embedded 1 documents
# 2025-10-29 15:22:55,177 - liuembeddings.vectorstore - INFO - Query returned 2 results
# INFO:liuembeddings.vectorstore:Query returned 2 results
# 2025-10-29 15:22:55,179 - liuembeddings.utils - INFO - Raw data cleaning........................
# INFO:liuembeddings.utils:Raw data cleaning........................
# Answer 1: machine learning is a powerful and rapidly growing method of data analysis... feature engineering is crucial for model performance......
# Answer 2: machine learning is a powerful and rapidly growing method of data analysis... feature engineering is crucial for model performance......
# CleanOutput
# {'id': 'doc_0_1761731532610_b8e6b5', 'document': 'machine learning is a powerful and rapidly growing method of data analysis... feature engineering is crucial for model performance...', 'metadata': {'source': 'ml_knowledge'}, 'distance': 0.7753744125366211}
# {'id': 'doc_0_1761731574740_84e140', 'document': 'machine learning is a powerful and rapidly growing method of data analysis... feature engineering is crucial for model performance...', 'metadata': {'source': 'ml_knowledge'}, 'distance': 0.7753744125366211}
